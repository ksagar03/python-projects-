# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2020-10-10 06:38:47--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights        5%[>                   ]  14.02M   385KB/s    eta 9m 19s

# %%
import numpy as np
import cv2
import os

# %%
LabelPath = "coco.names"
weightPath = "yolov3.weights"
confPath = "yolov3.cfg"

Labels = open(LabelPath).read().strip().split("\n")
YoloShape = (416, 416)
image = cv2.imread("Screenshot_2020-06-13_at_7.41.41_AM.png")
H, W = image.shape[:2]  #### we will use in for rectangle
Pre_image = cv2.dnn.blobFromImage(image, 1/255.0, YoloShape, swapRB = True)

# %%
Network = cv2.dnn.readNetFromDarknet(confPath, weightPath)
ln = Network.getUnconnectedOutLayersNames()

# %%
Network.setInput(Pre_image)
LayerOuts = Network.forward(ln)

# %%
for output in LayerOuts:
    for detection in output:
        scores = detection[5:]
        classId = np.argmax(scores)
        confidence = scores[classId]
        if float(confidence) > 0.8:
            Object = Labels[classId]
            if Object == "person":
                (centerX, centerY, width, height) = (detection[:4] * np.array([W, H, W, H])).astype("int")
                X, Y = int(centerX - (width/2)), int(centerY - (height/2))
                cv2.rectangle(image, (X, Y), (X+width, Y+height), (0, 0, 255), 2)
                cv2.putText(image, Object, (X, Y-20), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 0, 255), 2)
cv2.imwrite("DETECTED_IMAGE.jpg", image)
# Out:
# True

# %%
from PIL import Image

# %%
Image.open("DETECTED_IMAGE.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1440x900 at 0x128766B90>

# %%
# !wget https://wallpapercave.com/wp/wp2406637.jpg
# Out:
# --2020-10-10 07:40:19--  https://wallpapercave.com/wp/wp2406637.jpg
# Resolving wallpapercave.com (wallpapercave.com)... 51.222.47.58
# Connecting to wallpapercave.com (wallpapercave.com)|51.222.47.58|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 538660 (526K) [image/jpeg]
# Saving to: ‘wp2406637.jpg’
#
# wp2406637.jpg       100%[===================>] 526.04K   623KB/s    in 0.8s
#
# 2020-10-10 07:40:22 (623 KB/s) - ‘wp2406637.jpg’ saved [538660/538660]

# %%
# !wget https://www.techsimplus.com/media/Screenshot_2020-06-13_at_7.41.41_AM.png
